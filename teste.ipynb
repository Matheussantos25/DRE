# %%
import streamlit as st
import pandas as pd

st.title("📊 Simulador de Projeção de DRE")

tabs = st.tabs(["Receitas", "Custos", "Despesas", "Resumo (em breve)"])

with tabs[0]:  # Aba de Receitas
    st.header("📈 Projeção de Receitas")

    tipo_servico = st.text_input("Tipo de Serviço", value="Consulta")
    valor_venda = st.number_input("Valor de Venda (R$)", min_value=0.0, value=100.0)
    qtd_inicial = st.number_input("Quantidade Inicial", min_value=0, value=100)
    qtd_maxima = st.number_input("Quantidade Máxima", min_value=0, value=500)
    custo_unitario = st.number_input("Custo por Unidade (R$)", min_value=0.0, value=20.0)
    repasse_percentual = st.number_input("Repasse Médico (%)", min_value=0.0, max_value=100.0, value=30.0)
    crescimento_percentual = st.number_input("Crescimento Mensal da Quantidade (%)", min_value=0.0, value=5.0)
    meses = st.slider("Período de projeção (meses)", min_value=1, max_value=60, value=12)

    tipo_imposto = st.radio("Tipo de Imposto", ["Imposto Único (12%)", "Por Faixa de Faturamento"])

    if st.button("📊 Gerar Projeção"):
        dados = []
        quantidade = qtd_inicial
        total_receita = 0.0

        for mes in range(1, meses + 1):
            receita_bruta = quantidade * valor_venda
            custo_total = quantidade * custo_unitario
            repasse_valor = receita_bruta * (repasse_percentual / 100)
            total_receita += receita_bruta

            dados.append({
                "Mês": f"M{mes}",
                "Quantidade": round(quantidade),
                "Receita Operacional Bruta (R$)": receita_bruta,
                "Custo Total (R$)": custo_total,
                "Repasse Médico (R$)": repasse_valor
            })

            quantidade = min(quantidade * (1 + crescimento_percentual / 100), qtd_maxima)

        # --- Determinar alíquota ---
        if tipo_imposto == "Imposto Único (12%)":
            aliquota = 0.12
        else:
            faixas = [
                (0, 360000, 0.112),
                (360000, 720000, 0.135),
                (720000, 1800000, 0.16),
                (1800000, 3600000, 0.21),
                (3600000, 4800000, 0.33),
            ]
            aliquota = 0.0
            for inf, sup, perc in faixas:
                if inf < total_receita <= sup:
                    aliquota = perc
                    break
            if aliquota == 0.0:
                st.warning("Receita fora das faixas de tributação. Nenhum imposto calculado.")

        # --- Cálculo de imposto, ROL e lucro mês a mês ---
        for row in dados:
            receita_bruta = row["Receita Operacional Bruta (R$)"]
            imposto_mes = receita_bruta * aliquota
            receita_liquida = receita_bruta - imposto_mes
            row["Impostos (R$)"] = imposto_mes
            row["Receita Operacional Líquida (R$)"] = receita_liquida
            row["Lucro Bruto (R$)"] = receita_liquida - row["Custo Total (R$)"] - row["Repasse Médico (R$)"]

        df = pd.DataFrame(dados)

        st.subheader("📋 Tabela de Projeção")
        st.dataframe(df.style.format({
            "Receita Operacional Bruta (R$)": "R${:,.2f}",
            "Receita Operacional Líquida (R$)": "R${:,.2f}",
            "Custo Total (R$)": "R${:,.2f}",
            "Repasse Médico (R$)": "R${:,.2f}",
            "Impostos (R$)": "R${:,.2f}",
            "Lucro Bruto (R$)": "R${:,.2f}"
        }))

        st.subheader("📈 Gráfico Comparativo")
        st.line_chart(df.set_index("Mês")[[
            "Receita Operacional Bruta (R$)", 
            "Receita Operacional Líquida (R$)", 
            "Lucro Bruto (R$)"
        ]])

        st.subheader("📌 Resumo Anual")
        imposto_total = df["Impostos (R$)"].sum()
        st.metric("Receita Total Bruta", f"R$ {total_receita:,.2f}")
        st.metric("Imposto Total", f"R$ {imposto_total:,.2f}")
        st.metric("Alíquota Efetiva", f"{aliquota * 100:.2f}%")
# Out:
# 2025-05-26 09:12:36.257 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.897
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\msdof\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-05-26 09:12:36.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.907 Session state does not function when running a script without `streamlit run`
# 2025-05-26 09:12:36.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 09:12:36.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
